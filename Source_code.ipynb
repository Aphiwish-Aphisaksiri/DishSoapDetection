# %% [markdown]
# # This is the real notebook
# To see the result go to runs\detect\train21

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n.pt")  # load a pretrained model

# Train the model with a single GPU
results = model.train(data="data.yaml", epochs=100, imgsz=640, device=0)
# Out:
# Ultralytics 8.3.33  Python-3.11.10 torch-2.5.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %%
from ultralytics import YOLO

# Define a function to train the model with different arguments
def train_model(data, epochs, imgsz, batch, lr0, weight_decay, momentum, optimizer, device):
    # Load a pretrained model
    model = YOLO("yolo11n.pt")
    
    # Train the model with specified arguments
    results = model.train(
        data=data,
        epochs=epochs,
        imgsz=imgsz,
        batch=batch,
        lr0=lr0,
        weight_decay=weight_decay,
        momentum=momentum,
        optimizer=optimizer,
        device=device
    )
    
    return results

# Define the arguments to compare
training_configs = [
    {"epochs": 50, "imgsz": 640, "batch": 16, "lr0": 0.01, "weight_decay": 0.0005, "momentum": 0.937, "optimizer": "SGD", "device": 0},
    {"epochs": 50, "imgsz": 640, "batch": 16, "lr0": 0.001, "weight_decay": 0.0005, "momentum": 0.937, "optimizer": "Adam", "device": 0},
    {"epochs": 100, "imgsz": 640, "batch": 32, "lr0": 0.01, "weight_decay": 0.0001, "momentum": 0.9, "optimizer": "SGD", "device": 0},
    {"epochs": 100, "imgsz": 640, "batch": 32, "lr0": 0.001, "weight_decay": 0.0001, "momentum": 0.9, "optimizer": "Adam", "device": 0},
]

# Train the model with different configurations and compare results
for config in training_configs:
    print(f"Training with config: {config}")
    results = train_model(
        data="data.yaml",
        epochs=config["epochs"],
        imgsz=config["imgsz"],
        batch=config["batch"],
        lr0=config["lr0"],
        weight_decay=config["weight_decay"],
        momentum=config["momentum"],
        optimizer=config["optimizer"],
        device=config["device"]
    )
    print(f"Results: {results}")
# Out:
# Training with config: {'epochs': 50, 'imgsz': 640, 'batch': 16, 'lr0': 0.01, 'weight_decay': 0.0005, 'momentum': 0.937, 'optimizer': 'SGD', 'device': 0}
# New https://pypi.org/project/ultralytics/8.3.36 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.33  Python-3.11.10 torch-2.5.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %%
# "epochs": 100, "imgsz": 640, "batch": 32, "lr0": 0.01, "weight_decay": 0.0001, "momentum": 0.9, "optimizer": "SGD", "device": 0
from ultralytics import YOLO

# Define a function to train the model with different arguments
def train_model(data, epochs, imgsz, batch, lr0, weight_decay, momentum, optimizer, device):
    # Load a pretrained model
    model = YOLO("yolo11n.pt")
    
    # Train the model with specified arguments
    results = model.train(
        data=data,
        epochs=epochs,
        imgsz=imgsz,
        batch=batch,
        lr0=lr0,
        weight_decay=weight_decay,
        momentum=momentum,
        optimizer=optimizer,
        device=device
    )
    
    return results

# Define the arguments to compare
training_configs = [
    {"epochs": 100, "imgsz": 640, "batch": 32, "lr0": 0.01, "weight_decay": 0.0001, "momentum": 0.9, "optimizer": "SGD", "device": 0},
]

# Train the model with different configurations and compare results
for config in training_configs:
    print(f"Training with config: {config}")
    results = train_model(
        data="data.yaml",
        epochs=config["epochs"],
        imgsz=config["imgsz"],
        batch=config["batch"],
        lr0=config["lr0"],
        weight_decay=config["weight_decay"],
        momentum=config["momentum"],
        optimizer=config["optimizer"],
        device=config["device"]
    )
    print(f"Results: {results}")
# Out:
# Training with config: {'epochs': 100, 'imgsz': 640, 'batch': 32, 'lr0': 0.01, 'weight_decay': 0.0001, 'momentum': 0.9, 'optimizer': 'SGD', 'device': 0}
# New https://pypi.org/project/ultralytics/8.3.36 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.33  Python-3.11.10 torch-2.5.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n.yaml")  # build a new model from YAML
model = YOLO("yolo11n.pt")  # load a pretrained model (recommended for training)
model = YOLO("yolo11n.yaml").load("yolo11n.pt")  # build from YAML and transfer weights

# Train the model
results = model.train(data="data.yaml", epochs=10, imgsz=640)
# Out:
# Transferred 499/499 items from pretrained weights
# Ultralytics 8.3.33  Python-3.11.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %%
# RUN THIS OVERNIGHT (Take about 2 hours)
# {"epochs": 100, "imgsz": 640, "batch": 32, "lr0": 0.001, "weight_decay": 0.0001, "momentum": 0.9, "optimizer": "Adam", "device": 0}
from ultralytics import YOLO

# Define a function to train the model with different arguments
def train_model(data, epochs, imgsz, batch, lr0, weight_decay, momentum, optimizer, device):
    # Load a pretrained model
    model = YOLO("yolo11n.pt")
    
    # Train the model with specified arguments
    results = model.train(
        data=data,
        epochs=epochs,
        imgsz=imgsz,
        batch=batch,
        lr0=lr0,
        weight_decay=weight_decay,
        momentum=momentum,
        optimizer=optimizer,
        device=device
    )
    
    return results

# Define the arguments to compare
training_configs = [
    {"epochs": 100, "imgsz": 640, "batch": 32, "lr0": 0.001, "weight_decay": 0.0001, "momentum": 0.9, "optimizer": "Adam", "device": 0},
]

# Train the model with different configurations and compare results
for config in training_configs:
    print(f"Training with config: {config}")
    results = train_model(
        data="data.yaml",
        epochs=config["epochs"],
        imgsz=config["imgsz"],
        batch=config["batch"],
        lr0=config["lr0"],
        weight_decay=config["weight_decay"],
        momentum=config["momentum"],
        optimizer=config["optimizer"],
        device=config["device"]
    )
    print(f"Results: {results}")
# Out:
# Training with config: {'epochs': 100, 'imgsz': 640, 'batch': 32, 'lr0': 0.001, 'weight_decay': 0.0001, 'momentum': 0.9, 'optimizer': 'Adam', 'device': 0}
# New https://pypi.org/project/ultralytics/8.3.40 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.33  Python-3.11.10 torch-2.5.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n.pt")  # load a pretrained model (recommended for training)

# Train the model with a single GPU
results = model.train(data="data.yaml", epochs=100, imgsz=640, batch=32, lr0=0.001, weight_decay=0.0001, momentum=0.9, optimizer="Adam", device=0)
# Out:
# New https://pypi.org/project/ultralytics/8.3.49 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.33  Python-3.11.10 torch-2.5.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %%
import torch

print(f"Is CUDA supported by this system? {torch.cuda.is_available()}")
print(f"CUDA version: {torch.version.cuda}")

if torch.cuda.is_available():
    # Storing ID of current CUDA device
    cuda_id = torch.cuda.current_device()
    print(f"ID of current CUDA device: {torch.cuda.current_device()}")
    print(f"Name of current CUDA device: {torch.cuda.get_device_name(cuda_id)}")
else:
    print("CUDA is not available. Please check your CUDA installation.")
# Out:
# Is CUDA supported by this system? True
# CUDA version: 11.8
# ID of current CUDA device: 0
# Name of current CUDA device: NVIDIA GeForce RTX 3060 Laptop GPU

# %%
# !pip show torch torchvision
# Out:
# Name: torch
# Version: 2.5.1+cu118
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org/
# Author: PyTorch Team
# Author-email: packages@pytorch.org
# License: BSD-3-Clause
# Location: C:\Users\nealk\miniconda3\envs\image2\Lib\site-packages
# Requires: filelock, fsspec, jinja2, networkx, sympy, typing-extensions
# Required-by: torchaudio, torchvision, ultralytics, ultralytics-thop
# ---
# Name: torchvision
# Version: 0.20.1+cu118
# Summary: image and video datasets and models for torch deep learning
# Home-page: https://github.com/pytorch/vision
# Author: PyTorch Core Team
# Author-email: soumith@pytorch.org
# License: BSD
# Location: C:\Users\nealk\miniconda3\envs\image2\Lib\site-packages
# Requires: numpy, pillow, torch
# Required-by: ultralytics

# %%
# !pip install torch==2.0.0+cu118 torchvision==0.15.1+cu118 torchaudio==2.0.0+cu118 --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
#      ---------------------------------------- 0.0/2.6 GB ? eta -:--:--
#      ---------------------------------------- 0.0/2.6 GB 8.4 MB/s eta 0:05:12
#      ---------------------------------------- 0.0/2.6 GB 7.9 MB/s eta 0:05:29
#      ---------------------------------------- 0.0/2.6 GB 7.9 MB/s eta 0:05:31
#      ---------------------------------------- 0.0/2.6 GB 8.0 MB/s eta 0:05:25
#      ---------------------------------------- 0.0/2.6 GB 8.0 MB/s eta 0:05:27
#      ---------------------------------------- 0.0/2.6 GB 8.0 MB/s eta 0:05:24
#      ---------------------------------------- 0.0/2.6 GB 8.0 MB/s eta 0:05:25
#      ---------------------------------------- 0.0/2.6 GB 8.1 MB/s eta 0:05:23
#      ---------------------------------------- 0.0/2.6 GB 8.0 MB/s eta 0:05:24
#      ---------------------------------------- 0.0/2.6 GB 8.1 MB/s eta 0:05:23
# ...

# %%
from ultralytics import YOLO
import pandas as pd

# Load the trained model
model = YOLO("E:\\.Homeworks\\Homework is a god 4\\Suffering 1\\EGBI443 Image processing\\Project\\Image-processing-class-1\\runs\\detect\\train27\\weights\\best.pt")

# Run validation
results = model.val(data="data.yaml")
print(results)

# Convert results to a pandas DataFrame
results_df = pd.DataFrame([vars(result) for result in results])

# Save the DataFrame to an Excel file
results_df.to_excel("validation_results.xlsx", index=False)
# Out:
# Ultralytics 8.3.33  Python-3.11.10 torch-2.5.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# YOLO11n summary (fused): 238 layers, 2,587,027 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning E:\.Homeworks\Homework is a god 4\Suffering 1\EGBI443 Image processing\Project\Image-processing-class-1\valid\labels.cache... 252 images, 0 backgrounds, 0 corrupt: 100%|██████████| 252/252 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 16/16 [00:09<00:00,  1.67it/s]
#                    all        252      10736      0.746      0.777      0.792      0.718
#      ala_conc_amarillo        235        827      0.925      0.967      0.977      0.901
#          ala_conc_azul        202        540      0.871      0.939      0.961      0.875
#          ala_conc_rojo        217        782      0.879      0.954      0.974      0.872
# ...

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# Load the trained model
model = YOLO("E:\\.Homeworks\\Homework is a god 4\\Suffering 1\\EGBI443 Image processing\\Project\\Image-processing-class-1\\runs\\detect\\train27\\weights\\best.pt")

# Update the test image path
test_image_path = "E:\\.Homeworks\\Homework is a god 4\\Suffering 1\\EGBI443 Image processing\\Project\\Image-processing-class-1\\test\\images\\v5_c10260481-3218_r57-1_32_jpg.rf.f30fb5677b781430d3a3df4045d5e875.jpg"

# Load the test image
image = cv2.imread(test_image_path)

# Run prediction
results = model.predict(source=test_image_path)

# Display the result
result_image = results[0].plot()

# Convert BGR image to RGB
result_image_rgb = cv2.cvtColor(result_image, cv2.COLOR_BGR2RGB)

# Display the image using matplotlib
plt.imshow(result_image_rgb)
plt.axis('off')
plt.show()
# Out:
# image 1/1 E:\.Homeworks\Homework is a god 4\Suffering 1\EGBI443 Image processing\Project\Image-processing-class-1\test\images\v5_c10260481-3218_r57-1_32_jpg.rf.f30fb5677b781430d3a3df4045d5e875.jpg: 640x640 3 ala_conc_amarillos, 1 ala_conc_azul, 3 ala_conc_rojos, 12 cif_conc_bot_amarillas, 14 cif_conc_botella_verdes, 2 cif_conc_sachet_verdes, 5 magistral_con_amarillos, 3 magistral_con_azuls, 13.5ms
# Speed: 6.0ms preprocess, 13.5ms inference, 144.8ms postprocess per image at shape (1, 3, 640, 640)

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# Load the trained model
model = YOLO("E:\\.Homeworks\\Homework is a god 4\\Suffering 1\\EGBI443 Image processing\\Project\\Image-processing-class-1\\runs\\detect\\train27\\weights\\best.pt")

# Update the test image path
test_image_path = "E:\\.Homeworks\Homework is a god 4\\Suffering 1\\EGBI443 Image processing\\Project\\Image-processing-class-1\\test\\images\\v5_c10260481-4045_r57-1_32_jpg.rf.58d613c41322ff2f2eed28f2ce25c7f9.jpg"

# Load the test image
image = cv2.imread(test_image_path)

# Run prediction
results = model.predict(source=test_image_path)

# Display the result
result_image = results[0].plot()

# Convert BGR image to RGB
result_image_rgb = cv2.cvtColor(result_image, cv2.COLOR_BGR2RGB)

# Display the image using matplotlib
plt.imshow(result_image_rgb)
plt.axis('off')
plt.show()
# Out:
# image 1/1 E:\.Homeworks\Homework is a god 4\Suffering 1\EGBI443 Image processing\Project\Image-processing-class-1\test\images\v5_c10260481-4045_r57-1_32_jpg.rf.58d613c41322ff2f2eed28f2ce25c7f9.jpg: 640x640 3 ala_conc_amarillos, 4 ala_conc_rojos, 1 ala_crem_amarillo, 12 cif_conc_bot_amarillas, 9 magistral_con_amarillos, 5 magistral_con_azuls, 30.8ms
# Speed: 4.0ms preprocess, 30.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# Load the trained model
model = YOLO("E:\\.Homeworks\\Homework is a god 4\\Suffering 1\\EGBI443 Image processing\\Project\\Image-processing-class-1\\runs\\detect\\train27\\weights\\best.pt")

# Update the test image path
test_image_path = "E:\\.Homeworks\Homework is a god 4\\Suffering 1\\EGBI443 Image processing\\Project\\Image-processing-class-1\\test\images\\v59_c10825651-3162_r57-1_31_jpg.rf.31b4469df7725ca188a0f5b584d4e3a8.jpg"

# Load the test image
image = cv2.imread(test_image_path)

# Run prediction
results = model.predict(source=test_image_path)

# Display the result
result_image = results[0].plot()

# Convert BGR image to RGB
result_image_rgb = cv2.cvtColor(result_image, cv2.COLOR_BGR2RGB)

# Display the image using matplotlib
plt.imshow(result_image_rgb)
plt.axis('off')
plt.show()
# Out:
# image 1/1 E:\.Homeworks\Homework is a god 4\Suffering 1\EGBI443 Image processing\Project\Image-processing-class-1\test\images\v59_c10825651-3162_r57-1_31_jpg.rf.31b4469df7725ca188a0f5b584d4e3a8.jpg: 640x640 5 ala_conc_amarillos, 4 ala_conc_rojos, 2 ala_crem_amarillos, 2 ala_crem_blancos, 1 ala_crem_rosado, 5 ala_sachet_amarillos, 5 cif_conc_bot_amarillas, 6 cif_conc_botella_verdes, 3 cif_conc_sachet_amarillos, 3 cif_conc_sachet_verdes, 9 heroes, 9 magistral_con_amarillos, 4 magistral_con_azuls, 32.7ms
# Speed: 3.0ms preprocess, 32.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
